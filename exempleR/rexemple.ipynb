# %%
pow <- function(x, y) {
# function to print x raised to the power y
result <- x^y
print(paste(x,"raised to the power", y, "is", result))
}

# %%
pow(7,2)
# Out:
# [1] "7 raised to the power 2 is 49"

# %%
pow(5,2)
# Out:
# [1] "5 raised to the power 2 is 25"

# %%
x <- exp(2)

# %%
x
# Out:
# [1] 7.389056

# %%
x <- rnorm(22)
y <- rnorm(x)
plot(x, y)
# Out:
# plot without title

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”
